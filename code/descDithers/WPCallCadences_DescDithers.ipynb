# %% [markdown]
# This notebook runs `save_csv_dithers` for all the cadences included in the Cadence White Paper call; the outputs are saved in `/global/homes/a/awan/desc/wp_descDithers_csvs` at NERSC.
#
# Uses the `lsst` kernel that loads the local sims maf with the updated rotational dither stacker.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from save_csv_dithers import save_csv_dithers

# %%
dbs_path= '/global/cscratch1/sd/awan/dbs_wp_unzipped'
outDir = '/global/homes/a/awan/desc/wp_descDithers_csvs'

# %%
import os
os.listdir(dbs_path)
# Out:
# ['colossus_2665.db',
#  'colossus_2664.db',
#  'mothra_2045.db',
#  'kraken_2035.db',
#  'colossus_2667.db',
#  'pontus_2489.db',
#  'pontus_2002.db',
#  'kraken_2036.db',
#  'kraken_2026.db',
#  'pontus_2502.db']

# %%
# %%time
save_csv_dithers(dbs_path, outDir, rot_rand_seed=42, trans_rand_seed=42,
                 print_progress=True, show_diagnostic_plots=True)
# Out:
# Found files: ['colossus_2665.db', 'colossus_2664.db', 'mothra_2045.db', 'kraken_2035.db', 'colossus_2667.db', 'pontus_2489.db', 'pontus_2002.db', 'kraken_2036.db', 'kraken_2026.db', 'pontus_2502.db']
#
# Starting: colossus_2665.db
#
# Setting up for WFD translational dithers + rot dithers.
# Querying database SummaryAllProps with no constraint for columns ['fieldDec', 'fieldRA', 'filter', 'rotTelPos', 'night'].
# Found 2425849 visits
# Running:  [0]
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
#
# Setting up for DD translational dithers.
# Querying database SummaryAllProps with no constraint for columns ['fieldRA', 'fieldDec', 'night'].
# Found 2425849 visits
# Running:  [0]
# /global/common/software/lsst/cori-haswell-gcc/stack/w.2018.26_sim2.9.0/stack/miniconda3-4.3.21-10a4fa6/Linux64/sims_maf/2.9.0.sims/python/lsst/sims/maf/slicers/oneDSlicer.py:74: UserWarning: Both binsize and bins have been set; Using binsize 1.000000 only.
# ...

# %% [markdown]
# ##### We see that the translational dithers retain the overall characteristics of the pointing RA, Dec, while the rotational dithers change the distribution rather significantly (for most cadences) from strongly skewed to a more uniform one.
