# %% [markdown]
# This notebook displays diagnostic plots saved by `save_csv_dithers` for all the cadences included in the Cadence White Paper call; the outputs are read from `/global/homes/a/awan/desc/wp_descDithers_csvs` at NERSC.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image, display
import os

# %%
# dbs_path= '/global/cscratch1/sd/awan/dbs_wp_unzipped'
outDir = '/global/homes/a/awan/desc/wp_descDithers_csvs'

# %%
pngs = [f for f in os.listdir(outDir) if f.endswith('png')]

# %%
for png in pngs:
    display(Image(filename='%s/%s'%(outDir, png)) )

# %% [markdown]
# ##### We see that the translational dithers retain the overall characteristics of the pointing RA, Dec, while the rotational dithers change the distribution rather significantly (for most cadences) from strongly skewed to a more uniform one.
